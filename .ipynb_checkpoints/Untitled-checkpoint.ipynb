# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline
data = pd.read_csv("diabetes_data.csv")
data.Polyuria = data.Polyuria.eq('Yes').mul(True)
data.Gender = data.Gender.eq('Female').mul(True)
data.Polydipsia = data.Polydipsia.eq('Yes').mul(True)
data['sudden weight loss'] = data['sudden weight loss'].eq('Yes').mul(True)
data.weakness = data.weakness.eq('Yes').mul(True)
data.Polyphagia = data.Polyphagia.eq('Yes').mul(True)
data['Genital thrush'] = data['Genital thrush'].eq('Yes').mul(True)
data['visual blurring'] = data['visual blurring'].eq('Yes').mul(True)
data['Itching'] = data['Itching'].eq('Yes').mul(True)
data['Irritability'] = data['Irritability'].eq('Yes').mul(True)
data['delayed healing'] = data['delayed healing'].eq('Yes').mul(True)
data['partial paresis'] = data['partial paresis'].eq('Yes').mul(True)
data['muscle stiffness'] = data['muscle stiffness'].eq('Yes').mul(True)
data['Alopecia'] = data['Alopecia'].eq('Yes').mul(True)
data['Obesity'] = data['Obesity'].eq('Yes').mul(True)
data['class'] = data['class'].eq('Positive').mul(True)
data.drop('Age', inplace=True, axis=1)

# %%
import pandas as pd
from sklearn.datasets import make_classification
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# generate a dataset with boolean symptom attributes
X, y = make_classification(n_samples=1000, n_features=4,
                           n_informative=2, n_classes=2,
                           random_state=1)

# create a transaction encoder to convert the data into a transactional format
# te = TransactionEncoder()
# X_trans = te.fit_transform(data)

# # convert the data into a DataFrame
# df = pd.DataFrame(X_trans, columns=te.columns_)
# print(df.head())
# generate frequent itemsets and association rules
frequent_itemsets = apriori(data, min_support=0.3, use_colnames=True)
rules = association_rules(frequent_itemsets, metric='confidence', min_threshold=0.6)

# print the association rules
print(rules)
# Out:
#                antecedents               consequents  antecedent support  \
# 0                 (Gender)                   (class)            0.369231
# 1               (Polyuria)              (Polydipsia)            0.496154
# 2             (Polydipsia)                (Polyuria)            0.448077
# 3     (sudden weight loss)                (Polyuria)            0.417308
# 4               (Polyuria)      (sudden weight loss)            0.496154
# ..                     ...                       ...                 ...
# 59              (Polyuria)  (class, partial paresis)            0.496154
# 60       (weakness, class)              (Polydipsia)            0.419231
# 61  (weakness, Polydipsia)                   (class)            0.344231
# 62     (class, Polydipsia)                (weakness)            0.432692
# 63            (Polydipsia)         (weakness, class)            0.448077
#
#     consequent support   support  confidence      lift  leverage  conviction
# ...

# %%
rules.head()
# Out:
#             antecedents           consequents  antecedent support  \
# 0              (Gender)               (class)            0.369231
# 1            (Polyuria)          (Polydipsia)            0.496154
# 2          (Polydipsia)            (Polyuria)            0.448077
# 3  (sudden weight loss)            (Polyuria)            0.417308
# 4            (Polyuria)  (sudden weight loss)            0.496154
#
#    consequent support   support  confidence      lift  leverage  conviction
# 0            0.615385  0.332692    0.901042  1.464193  0.105473    3.886640
# 1            0.448077  0.371154    0.748062  1.669495  0.148839    2.190710
# 2            0.496154  0.371154    0.828326  1.669495  0.148839    2.934904
# 3            0.496154  0.317308    0.760369  1.532526  0.110259    2.102589
# 4            0.417308  0.317308    0.639535  1.532526  0.110259    1.616501

# %%
import matplotlib.pyplot as plt

# create a graph
fig, ax = plt.subplots()

# add edges to the graph
for ante, cons, conf in zip(rules['antecedents'], rules['consequents'], rules['confidence']):
    for i in ante:
        for j in cons:
            ax.annotate("", xy=(i, j), xytext=(i,j),
                arrowprops=dict(arrowstyle="-", color='black', alpha=conf, linewidth=2))

# add nodes to the graph
for node in set(list(rules['antecedents']) + list(rules['consequents'])):
    ax.text(list(node), 0, list(node), ha='center', va='center')
    plt.scatter(str(node), 0)

# Customize plot 
plt.xlim(-1, len(set(list(rules['antecedents']) + list(rules['consequents']))))
plt.ylim(-1, 1)
plt.axis('off')
plt.show()
# Out:
# frozenset({'delayed healing'})
# frozenset({'Polyuria', 'Polydipsia'})
# frozenset({'class', 'partial paresis'})
# frozenset({'Polyuria', 'Polyphagia'})
# frozenset({'partial paresis', 'Polyuria'})
# frozenset({'sudden weight loss'})
# frozenset({'class', 'Polyphagia'})
# frozenset({'weakness', 'Polydipsia'})
# frozenset({'class', 'Polyuria'})
# frozenset({'Polydipsia'})
# frozenset({'class'})
# frozenset({'Polyuria'})
# frozenset({'weakness'})
# frozenset({'Polyphagia'})
# frozenset({'visual blurring'})
# frozenset({'partial paresis'})
# frozenset({'Itching'})
# frozenset({'weakness', 'class'})
# frozenset({'weakness', 'Polyuria'})
# frozenset({'class', 'sudden weight loss'})
# frozenset({'sudden weight loss', 'Polyuria'})
# frozenset({'class', 'Polydipsia'})
# frozenset({'Gender'})
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ...
